# %% [markdown]
# # Plotting notebook

# %% [markdown]
# ### Import Required Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Read in results

# %% [markdown]
# ### Plot Results

# %%
plt.plot(t,z)
for i in range(1,5):
    plt.plot([0,1],[(z0-r)*COR**(2*i)+r, (z0-r)*COR**(2*i)+r])
plt.xlabel("time (s)")
plt.ylabel("height (m)")
plt.show()
