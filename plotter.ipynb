# %% [markdown]
# # Plotting notebook

# %% [markdown]
# ### Import Required Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Read in results

# %%
with open("results_cpp.txt") as f:
    lines = f.readlines()
    z = [line.split()[0] for line in lines] # the value inside the bracktes indicates what separates the data
    t = [line.split()[2] for line in lines] #t is the second split part because the first one is the comma and the last is \n

    #split splits a string into a list
    
#print(z)
#print(t)

# %% [markdown]
# ### Plot Results

# %%
plt.plot(np.asarray(t, float), np.asarray(z, float), c = 'b')

#plotting does not work well with lists, so np.asarray is used in order to make it an array

plt.xlabel("time (s)")
plt.ylabel("height (m)")
plt.title("Single grain DEM C++")

plt.show()
